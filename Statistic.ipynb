# %% [markdown]
# # Statistic

# %% [markdown]
# ## Import all Libery

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

import random

# %% [markdown]
# # First topic Population ...

# %%
dataset= pd.read_csv("Zomato data .csv")
dataset     # All data in csv or Excel or other Source are Population ......So we are called Population to Dataset
# Out:
#                       name online_order book_table   rate  votes  \
# 0                    Jalsa          Yes        Yes  4.1/5    775
# 1           Spice Elephant          Yes         No  4.1/5    787
# 2          San Churro Cafe          Yes         No  3.8/5    918
# 3    Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4            Grand Village           No         No  3.8/5    166
# ..                     ...          ...        ...    ...    ...
# 143       Melting Melodies           No         No  3.3/5      0
# 144        New Indraprasta           No         No  3.3/5      0
# 145           Anna Kuteera          Yes         No  4.0/5    771
# 146                 Darbar           No         No  3.0/5     98
# 147          Vijayalakshmi          Yes         No  3.9/5     47
#
#      approx_cost(for two people) listed_in(type)
# 0                            800          Buffet
# 1                            800          Buffet
# ...

# %% [markdown]
# # Simple Data...

# %% [markdown]
# ### Simple Data are Those data which are Repesentative Data  ,Randomly BE selected ,and They are Subset of data

# %%
import random

sam = dataset["votes"]  

sample_data = []


for i in range(1, 51):  
    value = random.choice(sam)  
    sample_data.append(value)   

for count, value in enumerate(sample_data, start=1):
    print(f"{count}) {value}")
# Out:
# 1) 804
# 2) 4
# 3) 104
# 4) 787
# 5) 11
# 6) 146
# 7) 130
# 8) 55
# 9) 23
# 10) 39
# 11) 1720
# 12) 286
# 13) 21
# 14) 93
# 15) 11
# 16) 104
# 17) 45
# 18) 918
# 19) 66
# 20) 679
# 21) 918
# 22) 144
# 23) 918
# 24) 245
# 25) 52
# 26) 4
# 27) 28
# 28) 0
# 29) 90
# 30) 31
# 31) 164
# 32) 14
# 33) 0
# 34) 90
# 35) 8
# 36) 14
# 37) 345
# 38) 0
# 39) 354
# 40) 90
# 41) 0
# 42) 283
# 43) 6
# 44) 25
# 45) 324
# 46) 0
# 47) 130
# 48) 230
# 49) 0
# 50) 22

# %%
sample_data
# Out:
# [804,
#  4,
#  104,
#  787,
#  11,
#  146,
#  130,
#  55,
#  23,
#  39,
#  1720,
#  286,
#  21,
#  93,
#  11,
#  104,
#  45,
#  918,
#  66,
#  679,
#  918,
#  144,
#  918,
#  245,
#  52,
#  4,
#  28,
#  0,
#  90,
#  31,
#  164,
#  14,
#  0,
#  90,
#  8,
#  14,
#  345,
#  0,
#  354,
#  90,
#  0,
#  283,
#  6,
#  25,
#  324,
#  0,
#  130,
#  230,
#  0,
#  22]

# %%
len(sample_data)
# Out:
# 50

# %% [markdown]
# ## Perform EDA

# %%
dataset.isnull().sum()                # We check the NAN Value in Dataset
# Out:
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# approx_cost(for two people)    0
# listed_in(type)                0
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         148 non-null    object
#  1   online_order                 148 non-null    object
#  2   book_table                   148 non-null    object
#  3   rate                         148 non-null    object
#  4   votes                        148 non-null    int64
#  5   approx_cost(for two people)  148 non-null    int64
#  6   listed_in(type)              148 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 8.2+ KB

# %%
dataset.shape
# Out:
# (148, 7)

# %%
ax=sns.countplot(x= "online_order" , data =dataset , hue = "online_order")
for p in ax.patches:
    ax.annotate(f'{p.get_height() * 100 / len(dataset):.1f}%', 
                (p.get_x() + p.get_width() / 2, p.get_height()), 
                ha='center')
plt.show()

# %%
dataset["listed_in(type)"].unique()
# Out:
# array(['Buffet', 'Cafes', 'other', 'Dining'], dtype=object)

# %%
dataset["listed_in(type)"].value_counts()
# Out:
# listed_in(type)
# Dining    110
# Cafes      23
# other       8
# Buffet      7
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 4))
ax = sns.barplot(
    y="approx_cost(for two people)",
    x="listed_in(type)",  
    data=dataset,
    hue="listed_in(type)"
)

# Properties for bar plot
ax.set_xlabel("Cosine type")                   
ax.set_ylabel("Approx Cost (for two)") 
ax.set_title("Approximate Cost by Cosine")  
plt.xticks(rotation=45)  
  

plt.show()

# %% [markdown]
# # Now Statistic Operation

# %% [markdown]
# ## For Staistical Operation We need Other Dataset

# %%
df= pd.read_csv(r"C:\Users\DELL\Desktop\min project working\Machine Learning PRactice//Data.csv")
df
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
# Math Formula ... X(bar) = sum of all  oberservation data/tota number
mean = np.sum(df["Age"])/len(df["Age"])
mean
# Out:
# 34.9

# %%
df["Age"].mean()
# Out:
# 38.77777777777778

# %%
np.sum(df["Age"])
# Out:
# 349.0

# %%
349.0/len(df["Age"])
# Out:
# 34.9

# %% [markdown]
# ## So these Columns Contain NAN value....so remove

# %%
from sklearn .impute import SimpleImputer
si = SimpleImputer()

df[["Age","Salary"]] = si.fit_transform(df[["Age" , "Salary"]])
df["Age"]
# Out:
# 0    44.000000
# 1    27.000000
# 2    30.000000
# 3    38.000000
# 4    40.000000
# 5    35.000000
# 6    38.777778
# 7    48.000000
# 8    50.000000
# 9    37.000000
# Name: Age, dtype: float64

# %%
mean = np.sum(df["Age"])/len(df["Age"])
mean
# Out:
# 38.77777777777778

# %%
df["Age"].mean()
# Out:
# 38.77777777777778

# %%
ax=sns.scatterplot(x= df ["Age"] , y = df["Salary"] )
sns.lineplot(x= df["Age"] , y = df["Salary"])
# Out:
# <Axes: xlabel='Age', ylabel='Salary'>

# %%
mn = np.mean(df["Age"])


bins = np.arange(25, 51, 2)


sns.histplot(x=df["Age"], data=df, bins=bins, color="skyblue",)


plt.axvline(mn, color="r", label=f"Mean Age ({mn:.2f})")
          # axv  for vertical direction ....keep in mind

plt.xlabel("Age")
plt.ylabel("Frequency")
plt.title("Age Distribution with Mean Age Line")
plt.legend()

plt.show()

# %% [markdown]
# # Now Median OF Dataset..

# %% [markdown]
# ## Median are middle value ....
# ### Median are two Type....
#                  ### 1.) Even Median ...2.) Odd Median

# %%
miden = df["Salary"].median()
miden
# Out:
# 62388.88888888889

# %%
bins = np.arange(43000, 83000.0 ,10000)
sns.histplot(x = df["Salary"] , data =df , bins = bins ,color= "b" )

plt.axvline(miden, color  = "r",linestyle= "--" , label=f"Median of  Age ({miden:.2f})")
plt.legend()
plt.show()

# %% [markdown]
# # Measure OF Dispersion

# %% [markdown]
# ## !.) Range..
#            ### range is the difference between the maximum and minimum values in the dataset

# %%
a=df["Salary"].max()
b= df["Salary"].min()
Range = a - b
print(f"This is Range {Range}")
# Out:
# This is Range 35000.0

# %% [markdown]
# # 2.) Variance
#            ## they are check the spreadness of Dataset(how much data away form the mean)

# %%
variance = df["Age"].var()
variance        # squre of the Standerd value is called Variance
# Out:
# 52.617283950617285

# %%
np.sqrt(52.617283950617285)      # Squre root of Variance is called Standerd Deviation
# Out:
# 7.253777219533095

# %%
sns.kdeplot(x = df["Age"] , data = df)

plt.axvline(mn, color="r",  label=f"Mean Age ({mn:.2f})")
plt.show()

# %%
# Calculate the mean and variance of the "Age" column
mean_age = df["Age"].mean()
variance_age = df["Age"].var()
std_dev_age = np.sqrt(variance_age)  # Standard deviation is the square root of variance

# Plot histogram of Age
sns.histplot(df["Age"], bins=np.arange(25, 51, 2), color="skyblue", kde=True)

# Plot the mean as a red vertical line
plt.axvline(mean_age, color="red", linestyle="--", label=f"Mean Age ({mean_age:.2f})")

# Plot lines for one standard deviation around the mean
plt.axvline(mean_age - std_dev_age, color="orange", linestyle=":", label=f"Mean - 1 Std Dev ({mean_age - std_dev_age:.2f})")
plt.axvline(mean_age + std_dev_age, color="orange", linestyle=":", label=f"Mean + 1 Std Dev ({mean_age + std_dev_age:.2f})")

# Add labels and title
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.title("Age Distribution with Mean and Standard Deviation Range")
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# # Standered Deviation ...
#       ## The Square root of Variance is called Std

# %%
df["Age"].std()           # Square Root of The Varvanice Deviation is called Standerd Davation
# Out:
# 7.253777219533095

# %%
7.253777219533095**2     # Square of The Standered Deviation is called Variance
# Out:
# 52.61728395061728

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate the mean and standard deviation of the "Age" column
mean_age = df["Age"].mean()
std_dev_age = df["Age"].std()  # Standard deviation directly using std()

# Set up the plot
plt.figure(figsize=(10, 6))

# Plot histogram of Age
sns.histplot(df["Age"], bins=np.arange(25, 51, 2), color="skyblue", stat="density", kde=False, label='Histogram')

# Overlay the kernel density estimate
sns.kdeplot(df["Age"], color='blue', label='KDE')

# Plot the mean as a red vertical line
plt.axvline(mean_age, color="red", linestyle="--", label=f"Mean Age ({mean_age:.2f})")

# Plot lines for one standard deviation around the mean
plt.axvline(mean_age - std_dev_age, color="orange", linestyle=":", label=f"Mean - 1 Std Dev ({mean_age - std_dev_age:.2f})")
plt.axvline(mean_age + std_dev_age, color="orange", linestyle=":", label=f"Mean + 1 Std Dev ({mean_age + std_dev_age:.2f})")

# Add labels and title
plt.xlabel("Age")
plt.ylabel("Density")
plt.title("Age Distribution with Mean and Standard Deviation")
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# # Outlier Deduction

# %% [markdown]
# ## Outlier are Out of range ,,,[2,3,4,5,5,6,7,7,8,100,2000,]

# %% [markdown]
# ### for Oulier...
#              you need Percential , Quential  , InterQuertial Range  , 25% , 75% , 90%...

# %%
data = pd.read_csv("Zomato data .csv")
data.shape
# Out:
# (148, 7)

# %%
data.describe()
# Out:
#              votes  approx_cost(for two people)
# count   148.000000                   148.000000
# mean    264.810811                   418.243243
# std     653.676951                   223.085098
# min       0.000000                   100.000000
# 25%       6.750000                   200.000000
# 50%      43.500000                   400.000000
# 75%     221.750000                   600.000000
# max    4884.000000                   950.000000

# %%
data["votes"].max()
# Out:
# 4884

# %%
plt.subplot(1,2,1)
sns.kdeplot(x= data["votes"] , data = data)
plt.subplot(1,2,2)
sns.boxplot(x = new_dataset["votes"], data  =data)
# Out:
# <Axes: xlabel='votes'>

# %% [markdown]
# ### in Votes columns you see the maximum value are 4884

# %%
q1=data["votes"].quantile(0.25)    # they are divide in Equal part i.e 25% and 75%
q3= data["votes"].quantile(0.75)

# %%
IQR  = q3 - q1
IQR
# Out:
# 215.0

# %%
min_range = q1 -(1.5*IQR)
max_range = q3 + (1.5*IQR)
print(f"This Minimum range : {min_range} &  the Maximum Range Range OF this Columns : {max_range}")
# Out:
# This Minimum range : -315.75 &  the Maximum Range Range OF this Columns : 544.25

# %% [markdown]
# ### Now Put the Condation

# %%
new_dataset = data[data["votes"]<=max_range ]

# %%
new_dataset.shape
# Out:
# (129, 7)

# %%
sns.kdeplot(x= new_dataset["votes"] , data = new_dataset)
plt.show()

# %%
sns.boxplot(x =new_dataset["votes"] ,data = new_dataset )
# Out:
# <Axes: xlabel='votes'>

# %%
data["votes"].info()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[109], line 1
# ----> 1 data["votes"].info()
#
# TypeError: list indices must be integers or slices, not str

# %%
z_score = data["votes"] - (data["votes"].mean())/(data["votes"].std())

z_score
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 z_score = data["votes"] - (data["votes"].mean())/(data["votes"].std())
#       3 z_score
#
# TypeError: list indices must be integers or slices, not str
