# %% [markdown]
# # Importing All Libery Of Python

# %%
import pandas as pd
import seaborn as sns
import matplotlib .pyplot as plt

# %% [markdown]
# # Upload CSV File

# %%
dataset = pd.read_csv("titanic_dataset.csv")
dataset.head(50)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %%
dataset.shape
# Out:
# (891, 12)

# %%
dataset.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# #   INTERQURTILE RANGE

# %%
plt.figure(figsize = (15 ,5))
sns.boxplot(x = dataset["Fare"]  , data = dataset)
plt.show()

# %%
Q1 = dataset["Fare"].quantile(0.25)
Q3 = dataset["Fare"].quantile(0.75)

# %%
IQR =  Q3  - Q1

# %%
min_range = Q1 - (1.5*IQR)
max_range = Q3 + (1.5*IQR)

# %%
print(min_range , max_range)
# Out:
# -26.724 65.6344

# %%
 new_dataset= dataset[dataset["Fare"]<=max_range]

# %%
new_dataset.shape
# Out:
# (775, 12)

# %% [markdown]
# # Preactical WOrking.....

# %%
dataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dataset .info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
dataset["PassengerId"].shape
# Out:
# (891,)

# %%
Q1 = dataset["PassengerId"].quantile(0.25)
Q3 = dataset["PassengerId"].quantile(0.75)

# %%
IQR = Q3 - Q1

# %%
min_range = Q1  - (1.5*IQR)
max_range = Q3 + (2.5*IQR)
print(min_range , max_range)
# Out:
# -444.0 1781.0

# %%
new_dataset_2 = dataset[dataset["PassengerId"]<=max_range]

# %%
new_dataset_2["PassengerId"].shape
# Out:
# (891,)

# %% [markdown]
# # . ..........  Z Score  ..............

# %%
dataset_2 = pd.read_csv("titanic_dataset.csv")
dataset_2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dataset_2.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
dataset_2.shape
# Out:
# (891, 12)

# %%
sns.boxplot( x = dataset_2["Fare" ],data= dataset_2)
# Out:
# <Axes: xlabel='Fare'>

# %%
z_score = dataset_2["Fare"] - (dataset_2["Fare"].mean())/(dataset_2["Fare"].std())

z_score
# Out:
# 0       6.601942
# 1      70.635242
# 2       7.276942
# 3      52.451942
# 4       7.401942
#          ...
# 886    12.351942
# 887    29.351942
# 888    22.801942
# 889    29.351942
# 890     7.101942
# Name: Fare, Length: 891, dtype: float64

# %%
 newdagtaset_2= dataset_2[dataset_2["Fare"]<=mix_range]

# %%
 newdagtaset_2.shape
# Out:
# (871, 12)
